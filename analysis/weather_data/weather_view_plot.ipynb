# %%
from weather import get_weather_data

# %%
# Gets data from Frost API, cleaning data and store as Dataframe
df = get_weather_data('2017-02-01', '2017-03-01')
# Out:
# Data retrieved from frost.met.no!

# %%
df.head(10)
# Out:
#                             sourceId                        elementId  value  \
# referenceTime
# 2017-02-01 06:00:00+00:00  SN18815:0  sum(precipitation_amount PT12H)    0.0
# 2017-02-01 06:00:00+00:00  SN18815:0       min(air_temperature PT12H)   -0.8
# 2017-02-01 06:00:00+00:00  SN18815:0       max(air_temperature PT12H)   -0.3
# 2017-02-02 06:00:00+00:00  SN18815:0  sum(precipitation_amount PT12H)    0.6
# 2017-02-02 06:00:00+00:00  SN18815:0       min(air_temperature PT12H)    0.2
# 2017-02-02 06:00:00+00:00  SN18815:0       max(air_temperature PT12H)    0.5
# 2017-02-03 06:00:00+00:00  SN18815:0  sum(precipitation_amount PT12H)    0.7
# 2017-02-03 06:00:00+00:00  SN18815:0       min(air_temperature PT12H)   -0.6
# 2017-02-03 06:00:00+00:00  SN18815:0       max(air_temperature PT12H)   -0.2
# 2017-02-04 06:00:00+00:00  SN18815:0  sum(precipitation_amount PT12H)    0.0
#
#                            unit timeOffset
# referenceTime
# 2017-02-01 06:00:00+00:00    mm       PT6H
# 2017-02-01 06:00:00+00:00  degC       PT6H
# 2017-02-01 06:00:00+00:00  degC       PT6H
# 2017-02-02 06:00:00+00:00    mm       PT6H
# 2017-02-02 06:00:00+00:00  degC       PT6H
# 2017-02-02 06:00:00+00:00  degC       PT6H
# 2017-02-03 06:00:00+00:00    mm       PT6H
# 2017-02-03 06:00:00+00:00  degC       PT6H
# 2017-02-03 06:00:00+00:00  degC       PT6H
# 2017-02-04 06:00:00+00:00    mm       PT6H

# %%
from weather import split_dataframe, plot_precipitation, plot_temperature

# %%
precipitation, max_temp, min_temp = split_dataframe(df)

plot_precipitation(precipitation)
plot_temperature(max_temp, min_temp)
