# %% [markdown]
# # Historic Weather Data
# ### The Notebook displays example responses and plots

# %%
from weather import get_weather_data, split_dataframe, plot_precipitation, plot_temperature

# %%
# Gets data from Frost API, cleaning data and store as Dataframe
df = get_weather_data('2018-05-01', '2018-08-01')
# Out:
# Data retrieved from frost.met.no!

# %% [markdown]
# ## Display weather data
# The first ten rows returned by the API.

# %%
df.head(10)
# Out:
#                             sourceId                        elementId  value  \
# referenceTime
# 2018-05-01 06:00:00+00:00  SN18815:0  sum(precipitation_amount PT12H)    8.7
# 2018-05-01 06:00:00+00:00  SN18815:0       min(air_temperature PT12H)    3.1
# 2018-05-01 06:00:00+00:00  SN18815:0       max(air_temperature PT12H)   10.9
# 2018-05-02 06:00:00+00:00  SN18815:0  sum(precipitation_amount PT12H)    0.5
# 2018-05-02 06:00:00+00:00  SN18815:0       min(air_temperature PT12H)    5.7
# 2018-05-02 06:00:00+00:00  SN18815:0       max(air_temperature PT12H)    6.7
# 2018-05-03 06:00:00+00:00  SN18815:0  sum(precipitation_amount PT12H)    0.0
# 2018-05-03 06:00:00+00:00  SN18815:0       min(air_temperature PT12H)    5.9
# 2018-05-03 06:00:00+00:00  SN18815:0       max(air_temperature PT12H)    9.8
# 2018-05-04 06:00:00+00:00  SN18815:0  sum(precipitation_amount PT12H)    0.0
#
#                            unit timeOffset
# referenceTime
# 2018-05-01 06:00:00+00:00    mm       PT6H
# 2018-05-01 06:00:00+00:00  degC       PT6H
# 2018-05-01 06:00:00+00:00  degC       PT6H
# 2018-05-02 06:00:00+00:00    mm       PT6H
# 2018-05-02 06:00:00+00:00  degC       PT6H
# 2018-05-02 06:00:00+00:00  degC       PT6H
# 2018-05-03 06:00:00+00:00    mm       PT6H
# 2018-05-03 06:00:00+00:00  degC       PT6H
# 2018-05-03 06:00:00+00:00  degC       PT6H
# 2018-05-04 06:00:00+00:00    mm       PT6H

# %% [markdown]
# ## Plot precipitation and temperature

# %%
precipitation, max_temp, min_temp = split_dataframe(df)

# %%
plot_precipitation(precipitation)
plot_temperature(max_temp, min_temp)
